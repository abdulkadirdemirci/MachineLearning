# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score,r2_score
from sklearn.model_selection import train_test_split

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
house = pd.read_csv('/content/drive/MyDrive/veriler/housing.csv', header=None, delimiter=r"\s+", names=column_names)

# %%
df = house.copy()

# %%
df.sample(10)
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  RAD    TAX  \
# 326   0.30347   0.0   7.38     0  0.4930  6.312   28.9  5.4159    5  287.0
# 296   0.05372   0.0  13.92     0  0.4370  6.549   51.0  5.9604    4  289.0
# 281   0.03705  20.0   3.33     0  0.4429  6.968   37.2  5.2447    5  216.0
# 437  15.17720   0.0  18.10     0  0.7400  6.152  100.0  1.9142   24  666.0
# 120   0.06899   0.0  25.65     0  0.5810  5.870   69.7  2.2577    2  188.0
# 77    0.08707   0.0  12.83     0  0.4370  6.140   45.8  4.0905    5  398.0
# 182   0.09103   0.0   2.46     0  0.4880  7.155   92.2  2.7006    3  193.0
# 498   0.23912   0.0   9.69     0  0.5850  6.019   65.3  2.4091    6  391.0
# 310   2.63548   0.0   9.90     0  0.5440  4.973   37.8  2.5194    4  304.0
# 76    0.10153   0.0  12.83     0  0.4370  6.279   74.5  4.0522    5  398.0
#
#      PTRATIO       B  LSTAT  MEDV
# 326     19.6  396.90   6.15  23.0
# 296     16.0  392.85   7.39  27.1
# 281     14.9  392.23   4.59  35.4
# ...

# %%
X = df.drop("MEDV", axis = 1)

# %%
y= df["MEDV"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state = 99)

# %%
lr = LinearRegression()

# %%
linear_model = lr.fit(X_train,y_train)

# %%
y_pred= linear_model.predict(X_test)

# %% [markdown]
# # test ve cross valide edilmemiş verinin görselleştirilmesi

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
y_test_arr =np.array(y_test)

# %%
plt.figure(figsize=(20,10))
plt.plot(y_pred,label= "tahmin",linewidth= 3)
plt.plot(y_test_arr,label="test",alpha = 0.5,linewidth=2)
plt.legend()
plt.ylabel("araba fiyatı",fontsize=14)
plt.title("tahmin ve test verisi karşılaştırma",fontsize=18)
# Out:
# Text(0.5, 1.0, 'tahmin ve test verisi karşılaştırma')

# %%
linear_model.intercept_
# Out:
# 38.1337409092006

# %%
linear_model.coef_
# Out:
# array([-1.17377855e-01,  5.57762410e-02,  2.31319550e-02,  2.16442877e+00,
#        -1.37021359e+01,  3.49073798e+00,  4.05349330e-03, -1.50686399e+00,
#         2.94341317e-01, -1.23546855e-02, -9.68733966e-01,  7.79823008e-03,
#        -6.23490268e-01])

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
print("MODEL FORMÜLÜ:" +"MEDV = " + str("%.4f" % linear_model.intercept_) +" + "+
      "CRIM" + "*" + str("%.4f" % linear_model.coef_[0]) + " + " +
      "ZN" + "*" + str("%.4f" % linear_model.coef_[1]) + " + " +
      "INDUS"+ "*" + str("%.4f" % linear_model.coef_[2]) + " + " +
      "CHAS"+ "*" + str("%.4f" % linear_model.coef_[3]) + " + " +
      "NOX"+ "*" + str("%.4f" % linear_model.coef_[4]) + " + " +
      "RM"+ "*" + str("%.4f" % linear_model.coef_[5]) + " + " +
      "AGE"+ "*" + str("%.4f" % linear_model.coef_[6]) + " + " +
      "DIS"+ "*" + str("%.4f" % linear_model.coef_[7]) + " + " +
      "RAD"+ "*" + str("%.4f" % linear_model.coef_[8]) + " + " +
      "TAX"+ "*" + str("%.4f" % linear_model.coef_[9]) + " + " +
      "PTRATIO"+ "*" + str("%.4f" % linear_model.coef_[10]) + " + " +
      "B"+ "*" + str("%.4f" % linear_model.coef_[11]) + " + " +
      "LSTAT"+ "*" + str("%.4f" % linear_model.coef_[12]) + " + " 
      )
# Out:
# MODEL FORMÜLÜ:MEDV = 38.1337 + CRIM*-0.1174 + ZN*0.0558 + INDUS*0.0231 + CHAS*2.1644 + NOX*-13.7021 + RM*3.4907 + AGE*0.0041 + DIS*-1.5069 + RAD*0.2943 + TAX*-0.0124 + PTRATIO*-0.9687 + B*0.0078 + LSTAT*-0.6235 +
